# %% [markdown]
# <a href="https://colab.research.google.com/github/amanmaurya7/langchain_collab/blob/main/in_memory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 1.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
import os
os.environ["PPLX_API_KEY"] = "pplx-" # your perplexity api key here

# %%
from langchain_community.chat_models import ChatPerplexity
from langchain_core.messages import HumanMessage
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableLambda, RunnableWithMessageHistory
from langchain_core.runnables import RunnableSequence
from langchain_core.messages import trim_messages
from langchain_core.chat_history import InMemoryChatMessageHistory

llm = ChatPerplexity(model = 'sonar-pro', temperature=0.3, max_tokens = 50)

# %%
store = {}

def get_session(session_id:str):
  if session_id not in store:
    store[session_id] = InMemoryChatMessageHistory()
  messages = store[session_id].messages
  store[session_id] = InMemoryChatMessageHistory(messages = messages)
  return store[session_id]


# def get_session(session_id:str):
#   if session_id not in store:
#     store[session_id] = InMemoryChatMessageHistory()
#   messages = store[session_id].messages
#   trimmed = trim_messages(
#       messages = messages,
#       token_counter = len,
#       max_tokens = 3,
#       strategy='last',
#       start_on = 'human',
#       include_system = True,
#       allow_partial= False
#   )
#   store[session_id] = InMemoryChatMessageHistory(messages = trimmed)
#   return store[session_id]

# %%
chain = RunnableWithMessageHistory(llm, get_session)

# %%
response1 = chain.invoke('hello my name is Aman', config = {'configurable':{'session_id':'session1'}})
print(response1)
# Out:
# content='Hello, **Aman** Your name has rich multicultural origins, primarily meaning **"peace"**, **"tranquility"**, **"security"**, or **"protection"** across Sanskrit, Arabic, and other traditions.' additional_kwargs={'citations': ['https://momcozy.com/blogs/baby-names/aman', 'https://www.youtube.com/watch?v=11gN-0dNEwU', 'https://en.wikipedia.org/wiki/Aman_(Islam)', 'https://nameberry.com/b/girl-baby-name-aman', 'https://www.familysearch.org/en/surname?surname=aman']} response_metadata={} id='lc_run--019c2f4d-a3d5-7392-b90c-453a140ee0c8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 7, 'output_tokens': 50, 'total_tokens': 57}

# %%
response2 = chain.invoke('what is my name?', config = {'configurable':{'session_id':'session1'}})
print(response2)
# Out:
# content='**Your name is Aman.** It originates from Arabic and Sanskrit roots, meaning **"peace"**, **"safety"**, **"trust"**, **"security"**, or **"protection"** in these traditions' additional_kwargs={'citations': ['https://www.wisdomlib.org/names/aman', 'https://momcozy.com/blogs/baby-names/aman', 'https://parentingpatch.com/baby-names/Aman/', 'https://en.wikipedia.org/wiki/Aman_(Islam)', 'https://babynames.com/name/aman', 'https://www.ancestry.com/first-name-meaning/Aman', 'https://www.familysearch.org/en/surname?surname=aman', 'https://nameberry.com/b/girl-baby-name-aman']} response_metadata={} id='lc_run--019c2f4e-05cc-7451-808a-5b72d724973e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 61, 'output_tokens': 50, 'total_tokens': 111}
